# %%
import pandas as pd

# %%
df = pd.read_excel("student_profiles.xlsx")

# %%
df.tail()
# Out:
#     Student ID Birthday
# 86          87      NaN
# 87          88      NaN
# 88          89     2013
# 89          90     2013
# 90          91     2012

# %%
df.nunique()
# Out:
# Student ID    91
# Birthday      76
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91 entries, 0 to 90
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student ID  91 non-null     int64
#  1   Birthday    81 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 1.5+ KB

# %%
df.isnull().sum()
# Out:
# Student ID     0
# Birthday      10
# dtype: int64

# %%
new_df = df.dropna(how = "any", axis = 0)

# %%
df["Birthday"]
# Out:
# 0     2012-09-03 00:00:00
# 1     2011-09-07 00:00:00
# 2     2011-04-08 00:00:00
# 3     2013-07-07 00:00:00
# 4     2012-04-05 00:00:00
#              ...
# 86                    NaN
# 87                    NaN
# 88                   2013
# 89                   2013
# 90                   2012
# Name: Birthday, Length: 91, dtype: object

# %%
quest_key = pd.read_excel("question_key.xlsx")

# %%
quest_key.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Type     6 non-null      object
#  1   Meaning  6 non-null      object
#  2   Example  2 non-null      object
# dtypes: object(3)
# memory usage: 272.0+ bytes

# %%
quest_key
# Out:
#   Type                                            Meaning  \
# 0    M  Factual recall: there is a sentence that basic...
# 1    H  Inference: they will have to infer information...
# 2  T/F  True or false question, which will require oth...
# 3    P  Purpose: understanding why the author writes s...
# 4    G  Grammar: questions testing spelling, punctuati...
# 5    V  Vocabualry: questions testing vocabulary knowl...
#
#                                         Example
# 0  He had black hair <- what colour is his hair
# 1                she smiled <- how did she feel
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN

# %%
quest_key["Meaning"][5]
# Out:
# 'Vocabualry: questions testing vocabulary knowledge'

# %%
worksheet_data = pd.read_excel("Worksheets\worksheet_data.xlsx")

# %%
worksheet_data
# Out:
#           fiction Unnamed: 1 Unnamed: 2             version  \
# 0             NaN        NaN        NaN  Date of Completion
# 1   Question Type   Question     Answer                Name
# 2               M          1          C                 NaN
# 3               M          2          C                 NaN
# 4               H          3          D                 NaN
# 5          M, T/F          4          C                 NaN
# 6               H          5          D                 NaN
# 7               H          6          D                 NaN
# 8               M          7          B                 NaN
# 9               M          8          C                 NaN
# 10              V          9          A                 NaN
# 11              V         10          C                 NaN
# 12              M         11          D                 NaN
# 13              G         12          D                 NaN
# 14              M         13          C                 NaN
# ...
